# %% [markdown]
# <a href="https://colab.research.google.com/github/yelbaz-technion/Constitutive-Modeling/blob/main/HW2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def compute_hyperelastic_stress(F, model, params):

  J = np.linalg.det(F)
  b = F @ F.T
  I_1 = np.trace(b)
  model = model.lower().strip().replace("-", " ").replace("_", " ")

  if model == "neo hookean":
    print("Using Neo-Hookean Compressible model")


  if model == "neo hookean incompressible":
  print("Using Neo-Hookean Compressible model")

  elif model == "mooney rivlin":
  print("Using Mooney-Rivlin model")

  else:
  print("Unknown Model")


F=1
params=1
compute_hyperelastic_stress(F,"mooney n",params)
# Out:
# Unknown Model
